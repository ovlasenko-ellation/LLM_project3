# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/ovlasenko-ellation/LLM_project3/refs/heads/main/Data/Sephora_all.csv'

# %%
df = pd.read_csv(data)
df.head()
# Out:
#                                        cosmetic_link      brand_name  \
# 0  https://www.sephora.com/product/summer-fridays...  Summer Fridays
# 1  https://www.sephora.com/product/glow-recipe-wa...     Glow Recipe
# 2  https://www.sephora.com/product/touchland-powe...       Touchland
# 3  https://www.sephora.com/product/the-ordinary-h...    The Ordinary
# 4  https://www.sephora.com/product/lip-sleeping-m...         LANEIGE
#
#                                        cosmetic_name num_customer  \
# 0              Lip Butter Balm for Hydration & Shine         6.7K
# 1         Watermelon Glow PHA + BHA Pore-Tight Toner         6.1K
# 2                Power Mist Hydrating Hand Sanitizer          845
# 3            Hyaluronic Acid 2% + B5 Hydrating Serum          539
# 4  Lip Sleeping Mask Intense Hydration with Vitam...        18.8K
#
#              price                                        ingredients  \
# 0          $24.00   -Shea and Murumuru Seed Butters: Natural moist...
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.isnull().sum()
# Out:
# cosmetic_link                    0
# brand_name                       0
# cosmetic_name                    0
# num_customer                    10
# price                            3
# ingredients                      0
# about                          244
# reviews                          0
# recommended                    866
# what_it_is                     264
# skin_type                      671
# skincare_concerns              689
# formulation                    984
# benefits                      2146
# highlighted_ingredients        903
# ingredient_callouts            674
# what_else_you_need_to_know     389
# clinical_results              1290
# clean_ingredients             1922
# new_ingredients                102
# dtype: int64

# %%
df.nunique()
# Out:
# cosmetic_link                 2179
# brand_name                     181
# cosmetic_name                 2179
# num_customer                   698
# price                          479
# ingredients                   2067
# about                         1869
# reviews                         34
# recommended                     21
# what_it_is                    1786
# skin_type                       55
# skincare_concerns              402
# formulation                     92
# benefits                        12
# highlighted_ingredients       1135
# ingredient_callouts            327
# what_else_you_need_to_know    1660
# clinical_results               821
# clean_ingredients              162
# new_ingredients               1854
# dtype: int64

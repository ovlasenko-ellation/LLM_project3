# %%
import pandas as pd

# %%
# Load the CSV file
file_path = 'https://raw.githubusercontent.com/ovlasenko-ellation/LLM_project3/refs/heads/main/Data/ingredientsList.csv'
df = pd.read_csv(file_path)

# %%
df.iloc[25]
# Out:
# name                                             NaN
# scientific_name       Euterpe Oleracea Fruit Extract
# short_description                                NaN
# what_is_it                                       NaN
# what_does_it_do                                  NaN
# who_is_it_good_for                                []
# who_should_avoid                                  []
# url                    https://renude.co/ingredients
# Name: 25, dtype: object

# %%
# Remove a specific row 
df = df.drop(index=25)

# %%
df.iloc[23:]
# Out:
#                           name scientific_name  \
# 23                  Aquagenium             NaN
# 24            Apple Stem Cells             NaN
# 26           Apple Polyphenols             NaN
# 27               Apple Extract             NaN
# 28        Anti-Ageing Peptides             NaN
# ..                         ...             ...
# 243               Zinc Sulfate             NaN
# 244                   Zinc PCA             NaN
# 245             Neoglucosamine             NaN
# 246                    Taurine             NaN
# 247  Sodium Ascorbyl Phosphate             NaN
#
#                                      short_description  \
# 23   A Bioderma exclusive ingredient, which is a bl...
# 24   Apple stem cells, also known as malus domestic...
# 26   Apple (like most plants), contains polyphenols...
# 27   Apple extract, also known as pyrus malus extra...
# 28   Many peptides function as anti-ageing ingredie...
# ..                                                 ...
# 243  The jury is still out on the efficacy of this ...
# 244  Zinc PCA is a component of the skin’s natural ...
# 245  A patented non-amino acid sugar which gently e...
# 246  In skin care, taurine is a powerful form of an...
# 247  Sodium Ascorbyl Phosphate (SAP) is a gentle an...
#
#                                             what_is_it  \
# 23   Aquagenium is a patented complex used in skinc...
# 24   Apple stem cells are derived from the stem cel...
# 26   Apple polyphenols are natural compounds found ...
# 27   Apple extract is derived from apples and is us...
# 28   Anti-aging peptides are synthetic or naturally...
# ..                                                 ...
# 243      An antibacterial ingredient used in skincare.
# 244  Zinc PCA is known to regulate sebum production...
# 245  Neoglucosamine is a patented skincare ingredie...
# 246  Taurine is an amino acid that’s naturally prod...
# 247        A gentle, water soluble form of Vitamin C.
#
#                                        what_does_it_do  \
# 23   The complex claims to:\r\n- Aims to increase t...
# 24   Apple stem cells offer potential benefits for ...
# 26   Apple polyphenols offer multiple benefits for ...
# 27   Apple extract offers multiple benefits for the...
# 28   They can help stimulate collagen production, i...
# ..                                                 ...
# 243  Zinc salts such as zinc gluconate, zinc PCA an...
# 244  Zinc salts such as zinc gluconate, zinc PCA an...
# 245  Neoglucosamine offers benefits such as:\n- Sup...
# 246  Helps support the skin barrier and protect aga...
# 247  Sodium ascorbyl phosphate helps brighten the s...
#
#                                     who_is_it_good_for  \
# 23   [' ', 'Dry and dehydrated skin', ' ', 'Pregnan...
# 24   [' ', 'Elasticity', ' ', 'Fine Lines', ' ', 'P...
# 26                                  [' ', 'Pregnancy']
# 27                                  [' ', 'Pregnancy']
# 28   [' ', 'Elasticity', ' ', 'Fine Lines', ' ', 'W...
# ..                                                 ...
# 243                                    [' ', 'Anyone']
# 244  [' ', 'Acne', ' ', 'Blackheads', ' ', 'Enlarge...
# 245  [' ', 'Blackheads', ' ', 'Elasticity', ' ', 'E...
# 246  [' ', 'Dry and dehydrated skin', ' ', 'Radianc...
# 247  [' ', 'Acne', ' ', 'Blackheads', ' ', 'Fine Li...
#
#                                       who_should_avoid  \
# 23                            [' ', 'Related Allergy']
# 24                            [' ', 'Related Allergy']
# 26                            [' ', 'Related Allergy']
# 27                            [' ', 'Related Allergy']
# 28                            [' ', 'Related Allergy']
# ..                                                 ...
# 243                           [' ', 'Related Allergy']
# 244                           [' ', 'Related Allergy']
# 245  [' ', 'Related Allergy', ' ', 'Impaired skin b...
# 246                           [' ', 'Related Allergy']
# 247  [' ', 'Related Allergy', ' ', 'Impaired skin b...
#
#                                                    url
# 23            https://renude.co/ingredients/aquagenium
# 24      https://renude.co/ingredients/apple-stem-cells
# 26     https://renude.co/ingredients/apple-polyphenols
# 27         https://renude.co/ingredients/apple-extract
# 28   https://renude.co/ingredients/anti-ageing-pept...
# ..                                                 ...
# 243         https://renude.co/ingredients/zinc-sulfate
# 244             https://renude.co/ingredients/zinc-pca
# 245       https://renude.co/ingredients/neoglucosamine
# 246              https://renude.co/ingredients/taurine
# 247  https://renude.co/ingredients/sodium-ascorbyl-...
#
# [224 rows x 8 columns]

# %%
# Remove a column 
df = df.drop(columns=['scientific_name'])

# %%
df
# Out:
#                              name  \
# 0    Alpha-Glucan Oligosaccharide
# 1                       Aloe Vera
# 2                       Allantoin
# 3                           Algin
# 4                   Algae Extract
# ..                            ...
# 243                  Zinc Sulfate
# 244                      Zinc PCA
# 245                Neoglucosamine
# 246                       Taurine
# 247     Sodium Ascorbyl Phosphate
#
#                                      short_description  \
# 0    Alpha-glucan oligosaccharide is in a class of ...
# 1    Aloe vera, also appear on ingredients lists as...
# 2    Allantoin occurs naturally in the body, but ca...
# 3    Algin, also known as sodium alginate, is a lar...
# 4    It is essentially an underwater plant, designe...
# ..                                                 ...
# 243  The jury is still out on the efficacy of this ...
# 244  Zinc PCA is a component of the skin’s natural ...
# 245  A patented non-amino acid sugar which gently e...
# 246  In skin care, taurine is a powerful form of an...
# 247  Sodium Ascorbyl Phosphate (SAP) is a gentle an...
#
#                                             what_is_it  \
# 0    Prebiotics are a type of non-digestible dietar...
# 1    Aloe vera is a skincare ingredient derived fro...
# 2    Allantoin is a skincare ingredient derived fro...
# 3    An extract from brown seaweed used as hydratin...
# 4    An incredibly interesting natural ingredient s...
# ..                                                 ...
# 243      An antibacterial ingredient used in skincare.
# 244  Zinc PCA is known to regulate sebum production...
# 245  Neoglucosamine is a patented skincare ingredie...
# 246  Taurine is an amino acid that’s naturally prod...
# 247        A gentle, water soluble form of Vitamin C.
#
#                                        what_does_it_do  \
# 0    Prebiotics offer benefits such as:\r\n\r\n- He...
# 1    Aloe vera offers multiple benefits for the ski...
# 2    Allantoin is a calming, anti-inflammatory, and...
# 3    In skincare products, it is used for its excel...
# 4    Algae extracts are multifunctional ingredients...
# ..                                                 ...
# 243  Zinc salts such as zinc gluconate, zinc PCA an...
# 244  Zinc salts such as zinc gluconate, zinc PCA an...
# 245  Neoglucosamine offers benefits such as:\n- Sup...
# 246  Helps support the skin barrier and protect aga...
# 247  Sodium ascorbyl phosphate helps brighten the s...
#
#                                     who_is_it_good_for  \
# 0    [' ', 'Acne', ' ', 'Blackheads', ' ', 'Redness...
# 1    [' ', 'Dry and dehydrated skin', ' ', 'Impaire...
# 2    [' ', 'Fine Lines', ' ', 'Impaired skin barrie...
# 3    [' ', 'Dry and dehydrated skin', ' ', 'Fine Li...
# 4    [' ', 'Dry and dehydrated skin', ' ', 'Fine Li...
# ..                                                 ...
# 243                                    [' ', 'Anyone']
# 244  [' ', 'Acne', ' ', 'Blackheads', ' ', 'Enlarge...
# 245  [' ', 'Blackheads', ' ', 'Elasticity', ' ', 'E...
# 246  [' ', 'Dry and dehydrated skin', ' ', 'Radianc...
# 247  [' ', 'Acne', ' ', 'Blackheads', ' ', 'Fine Li...
#
#                                       who_should_avoid  \
# 0                             [' ', 'Related Allergy']
# 1                             [' ', 'Related Allergy']
# 2                             [' ', 'Related Allergy']
# 3                             [' ', 'Related Allergy']
# 4                             [' ', 'Related Allergy']
# ..                                                 ...
# 243                           [' ', 'Related Allergy']
# 244                           [' ', 'Related Allergy']
# 245  [' ', 'Related Allergy', ' ', 'Impaired skin b...
# 246                           [' ', 'Related Allergy']
# 247  [' ', 'Related Allergy', ' ', 'Impaired skin b...
#
#                                                    url
# 0    https://renude.co/ingredients/alpha-glucan-oli...
# 1              https://renude.co/ingredients/aloe-vera
# 2              https://renude.co/ingredients/allantoin
# 3                  https://renude.co/ingredients/algin
# 4          https://renude.co/ingredients/algae-extract
# ..                                                 ...
# 243         https://renude.co/ingredients/zinc-sulfate
# 244             https://renude.co/ingredients/zinc-pca
# 245       https://renude.co/ingredients/neoglucosamine
# 246              https://renude.co/ingredients/taurine
# 247  https://renude.co/ingredients/sodium-ascorbyl-...
#
# [247 rows x 7 columns]

# %%
# Save the modified DataFrame back to CSV
df.to_csv(file_path, index=False)
